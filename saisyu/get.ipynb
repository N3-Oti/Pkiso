# %% [markdown]
# https://qiita.com/akita0724/items/694cc4e142d8d1d7fdaa

# %% [markdown]
# | 試験区分                         | コード |
# |-----------------------------------|------|
# | 応用情報技術者試験                 | ap    |
# | ITストラテジスト試験               | st    |
# | システムアーキテクト試験             | sa    |
# | プロジェクトマネージャ試験           | pw    |
# | ネットワークスペシャリスト試験       | nw    |
# | データベーススペシャリスト試験         | db    |
# | エンベデッドシステムスペシャリスト試験 | es    |
# | ITサービスマネージャ試験           | sm    |
# | システム監査技術者試験             | au    |
# | 情報処理安全確保支援士試験           | sc    |

# %%
import requests
from os import makedirs, path  # ファイル操作関連の関数をインポート
from time import sleep  # スリープ関数をインポート
from urllib.request import urlretrieve  # URLからファイルをダウンロードする関数をインポート


# ダウンロードしたい区分のコードを入れる
while 1:
    inp = input("ダウンロードしたい試験区分のコードを小文字で入力してください（例：ap）：\n修了する場合はqを入力してください。")
    if inp in ["ap", "st", "sa", "pw", "nw", "db", "es", "sm", "au", "sc"]:
        want = inp
        break
    elif inp == "q":
        print("プログラムを終了します。")
        exit()  # プログラムを終了
    else:
        raise ValueError("試験区分のコードを入力してください。")

# 過去問のURLを生成するためのIDとファイル名のパターンをリストで定義
# リスト定義内でf-stringを使うと、wantの代入が順番的に行われない
ids = [
    ["m42obm000000afqx-att", "2024r06h_"],
    ["ps6vr70000010d6y-att", "2023r05a_"],
    ["ps6vr70000010d6y-att", "2023r05h_"],
    ["gmcbt80000008smf-att", "2022r04a_"],
    ["gmcbt80000009sgk-att", "2022r04h_"],
    ["gmcbt8000000apad-att", "2021r03a_"],
    ["gmcbt8000000d5ru-att", "2021r03h_"],
    ["gmcbt8000000d05l-att", "2020r02o_"],
    ["gmcbt8000000dict-att", "2019r01a_"],
    ["gmcbt8000000ddiw-att", "2019h31h_"],
    ["gmcbt8000000f01f-att", "2018h30a_"],
    ["gmcbt8000000fabr-att", "2018h30h_"],
    ["gmcbt8000000fqpm-att", "2017h29a_"],
    ["gmcbt8000000fzx1-att", "2017h29h_"],
    ["gmcbt8000000g6fw-att", "2016h28a_"],
    ["gmcbt8000000gn5o-att", "2016h28h_"],
    ["gmcbt8000000gxj0-att", "2015h27a_"],
    ["ug65p90000000f52-att", "2015h27h_"],
    ["ug65p90000000ye5-att", "2014h26a_"],
    ["ug65p90000001dzu-att", "2014h26h_"],
    ["ug65p900000027za-att", "2013h25a_"],
    ["ug65p90000002e6g-att", "2013h25h_"],
    ["ug65p90000002h5m-att", "2012h24a_"],
    ["ug65p900000038er-att", "2012h24h_"],
    ["ug65p90000003ojp-att", "2011h23a_"],
    ["ug65p90000003ya2-att", "2011h23tokubetsu_"],
    ["ug65p90000004d6f-att", "2010h22a_"],
    ["ug65p90000004n2z-att", "2010h22h_"],
    ["gmcbt8000000f3yi-att", "2009h21a_"],
    ["ug65p90000009bhl-att", "2009h21h_"]
]

# 過去問のファイルの種類とファイル名のパターンをリストで定義
fileTypes1 = [
    ["am_qs", "am_ans", "pm_qs", "pm_ans"],  # ファイルの種類
    ["AM_問題", "AM_解答", "PM_問題", "PM_解答"]  # ファイル名のパターン
]
fileTypes2 = [
    ["koudo_am1_qs", "koudo_am1_ans", "sc_am2_qs", "sc_am2_ans", "sc_pm_qs", "sc_pm_ans"],
    ["AM1_問題", "AM1_解答", "AM2_問題", "AM2_解答", "PM_問題", "PM_解答"]
]
fileTypes3 = [
    ["koudo_am_qs", "koudo_am_ans", "pm_qs", "pm_ans"],  # ファイルの種類
    ["AM1_問題", "AM1_解答", "AM2_問題", "AM2_解答", "PM1_問題", "PM1_解答", "PM2_問題", "PM2_解答"]  # ファイル名のパターン
]

# 過去問のベースURLを定義
baseUrl = "https://www.ipa.go.jp/shiken/mondai-kaiotu/"

# 過去問のIDとファイル名のパターンをループ処理
for id in ids:
    # 季節を特定する
    filetmp = (id[1])[7]  # ファイル名のパターンから季節の情報を取得
    if filetmp == "h":  # "h" は春季を表す
        filetmp = "春季"
    elif filetmp == "a":  # "a" は秋季を表す
        filetmp = "秋季"
    else:
        filetmp = "特別"  # それ以外は特別試験


# 保存先ディレクトリを作成
    createDir = f"./{want}/{(id[1])[0:4]}/{filetmp}"  # 保存先ディレクトリのパスを生成

    # ディレクトリが存在するか判定
    if not path.exists(createDir):
        makedirs(createDir)  # ディレクトリが存在しない場合は作成

    # fileTypes1, fileTypes2, fileTypes3のどれを使うか判定
    if want == "ap":
        fileTypes = fileTypes1
    else:
        fileTypes = fileTypes3

    # ファイルの種類をループ処理
    for i, fileType in enumerate(fileTypes[0]):
        # 過去問のURLを生成
        if want == "ap":
            url = f"{baseUrl}{id[0]}/{id[1]}{want}_{fileType}.pdf"
        else:
            url = f"{baseUrl}{id[0]}/{id[1]}{want}_{fileType}.pdf"

        # 保存するファイル名を生成
        filen = f"{(id[1])[0:4]}{filetmp}-{fileTypes[1][i]}.pdf"

        # URLが存在するかチェック
        response = requests.head(url)
        if response.status_code == 200:  # URLが存在する場合
            # 過去問をダウンロード
            urlretrieve(url, f"{createDir}/{filen}")

            # ダウンロード完了メッセージを表示
            print(f"{filen} saved successfully.")
        else:  # URLが存在しない場合
            time_part = fileType.split("_")[0]  # am or pm を取得
            if time_part in ["am", "pm"]:
                for j in range(1, 3):  # 1と2をループ
                    new_fileType = fileType.replace(time_part, f"{time_part}{j}")  # am1_qs, am2_qs, pm1_qs, pm2_qs を生成
                    new_url = f"{baseUrl}{id[0]}/{id[1]}{new_fileType}.pdf"  # 新しいURLを生成
                    new_filen = f"{(id[1])[0:4]}{filetmp}-{fileTypes[1][i].replace(time_part.upper(), f'{time_part.upper()}{j}')}.pdf"  # 新しいファイル名を生成

                    # 新しいURLが存在するかチェック
                    response = requests.head(new_url)
                    if response.status_code == 200:
                        # 過去問をダウンロード
                        urlretrieve(new_url, f"{createDir}/{new_filen}")

                        # ダウンロード完了メッセージを表示
                        print(f"{new_filen} saved successfully.")
                        break  # ダウンロード成功したらループを抜ける
                    else:
                        print(f"{new_filen} is not found.")  # ファイルが見つからない場合はメッセージを表示

        # 3秒間スリープ
        sleep(3)
# すべての処理が完了したことを表示
print(f"{want}-DL-ok")
# Out:
# 2024春季-AM2_問題.pdf saved successfully.
# 2024春季-AM2_解答.pdf saved successfully.
# 2023秋季-AM2_問題.pdf saved successfully.
# 2023秋季-AM2_解答.pdf saved successfully.
# 2023春季-AM2_問題.pdf is not found.
# 2023春季-AM2_問題.pdf is not found.
# 2023春季-AM2_解答.pdf is not found.
# 2023春季-AM2_解答.pdf is not found.
# 2022秋季-AM2_問題.pdf is not found.
# 2022秋季-AM2_問題.pdf is not found.
# 2022秋季-AM2_解答.pdf is not found.
# 2022秋季-AM2_解答.pdf is not found.
# 2022春季-AM2_問題.pdf is not found.
# 2022春季-AM2_問題.pdf is not found.
# 2022春季-AM2_解答.pdf is not found.
# 2022春季-AM2_解答.pdf is not found.
# 2021秋季-AM2_問題.pdf is not found.
# 2021秋季-AM2_問題.pdf is not found.
# 2021秋季-AM2_解答.pdf is not found.
# 2021秋季-AM2_解答.pdf is not found.
# 2021春季-AM2_問題.pdf is not found.
# 2021春季-AM2_問題.pdf is not found.
# 2021春季-AM2_解答.pdf is not found.
# 2021春季-AM2_解答.pdf is not found.
# 2020特別-AM2_問題.pdf is not found.
# 2020特別-AM2_問題.pdf is not found.
# 2020特別-AM2_解答.pdf is not found.
# 2020特別-AM2_解答.pdf is not found.
# ...
