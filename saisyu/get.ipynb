# %% [markdown]
# https://qiita.com/akita0724/items/694cc4e142d8d1d7fdaa

# %% [markdown]
# # DL部

# %% [markdown]
# | 試験区分                         | コード |
# |-----------------------------------|------|
# | 応用情報技術者試験                 | ap    |
# | ITストラテジスト試験               | st    |
# | システムアーキテクト試験             | sa    |
# | プロジェクトマネージャ試験           | pw    |
# | ネットワークスペシャリスト試験       | nw    |
# | データベーススペシャリスト試験         | db    |
# | エンベデッドシステムスペシャリスト試験 | es    |
# | ITサービスマネージャ試験           | sm    |
# | システム監査技術者試験             | au    |
# | 情報処理安全確保支援士試験           | sc    |

# %%
import requests
import shutil
import tempfile
import os
from os import makedirs, path
from time import sleep
from urllib.request import urlretrieve

# 試験区分とコードの対応表
kamoku_codes = {
    "ap": "応用情報技術者試験",
    "st": "ITストラテジスト試験",
    "sa": "システムアーキテクト試験",
    "pw": "プロジェクトマネージャ試験",
    "nw": "ネットワークスペシャリスト試験",
    "db": "データベーススペシャリスト試験",
    "es": "エンベデッドシステムスペシャリスト試験",
    "sm": "ITサービスマネージャ試験",
    "au": "システム監査技術者試験",
    "sc": "情報処理安全確保支援士試験",
}

# 過去問のURLを生成するための情報
base_url = "https://www.ipa.go.jp/shiken/mondai-kaiotu/"
ids = [
    {"id": "m42obm000000afqx-att", "filename_ids": "2024r06a_"},
    {"id": "m42obm000000afqx-att", "filename_ids": "2024r06h_"},
    {"id": "ps6vr70000010d6y-att", "filename_ids": "2023r05a_"},
    {"id": "ps6vr70000010d6y-att", "filename_ids": "2023r05h_"},
    {"id": "gmcbt80000008smf-att", "filename_ids": "2022r04a_"},
    {"id": "gmcbt80000009sgk-att", "filename_ids": "2022r04h_"},
    {"id": "gmcbt8000000apad-att", "filename_ids": "2021r03a_"},
    {"id": "gmcbt8000000d5ru-att", "filename_ids": "2021r03h_"},
    {"id": "gmcbt8000000d05l-att", "filename_ids": "2020r02o_"},
    {"id": "gmcbt8000000dict-att", "filename_ids": "2019r01a_"},
    {"id": "gmcbt8000000ddiw-att", "filename_ids": "2019h31h_"},
    {"id": "gmcbt8000000f01f-att", "filename_ids": "2018h30a_"},
    {"id": "gmcbt8000000fabr-att", "filename_ids": "2018h30h_"},
    {"id": "gmcbt8000000fqpm-att", "filename_ids": "2017h29a_"},
    {"id": "gmcbt8000000fzx1-att", "filename_ids": "2017h29h_"},
    {"id": "gmcbt8000000g6fw-att", "filename_ids": "2016h28a_"},
    {"id": "gmcbt8000000gn5o-att", "filename_ids": "2016h28h_"},
    {"id": "gmcbt8000000gxj0-att", "filename_ids": "2015h27a_"},
    {"id": "ug65p90000000f52-att", "filename_ids": "2015h27h_"},
    {"id": "ug65p90000000ye5-att", "filename_ids": "2014h26a_"},
    {"id": "ug65p90000001dzu-att", "filename_ids": "2014h26h_"},
    {"id": "ug65p900000027za-att", "filename_ids": "2013h25a_"},
    {"id": "ug65p90000002e6g-att", "filename_ids": "2013h25h_"},
    {"id": "ug65p90000002h5m-att", "filename_ids": "2012h24a_"},
    {"id": "ug65p900000038er-att", "filename_ids": "2012h24h_"},
    {"id": "ug65p90000003ojp-att", "filename_ids": "2011h23a_"},
    {"id": "ug65p90000003ya2-att", "filename_ids": "2011h23tokubetsu_"},
    {"id": "ug65p90000004d6f-att", "filename_ids": "2010h22a_"},
    {"id": "ug65p90000004n2z-att", "filename_ids": "2010h22h_"},
    {"id": "gmcbt8000000f3yi-att", "filename_ids": "2009h21a_"},
    {"id": "ug65p90000009bhl-att", "filename_ids": "2009h21h_"},
]

# ファイルの種類とファイル名のパターン
file_types = {
    "am": ["am_qs", "am_ans"],
    "pm": ["pm_qs", "pm_ans", "pm_cmnt"],
    "am1": ["am1_qs", "am1_ans"],
    "am2": ["am2_qs", "am2_ans"],
    "pm1": ["pm1_qs", "pm1_ans", "pm1_cmnt"],
    "pm2": ["pm2_qs", "pm2_ans", "pm2_cmnt"],
}

# ファイル名のパターン
filename_codes = {
    "qs": "問題",
    "ans": "解答",
    "cmnt": "採点講評",
}

# ファイルをダウンロードする関数
def dl_file(url, filename, kamoku_code, year, season_name):
    if path.exists(filename):
        print(f"{filename} は既に存在するため、ダウンロードをスキップします。")
        return True

    response = requests.head(url)
    if response.status_code == 200:
        # ダウンロード前にフォルダを作成
        output_dir = create_output_dir(kamoku_code, year, season_name)
        output_path = path.join(output_dir, filename) # ファイルパスを生成
        urlretrieve(url, output_path)
        print(f"{filename} を保存しました。")
        sleep(3)
        return True
    else:
        print(f"{filename} は見つかりませんでした。")
        return False

# フォルダを作成する関数
def create_output_dir(kamoku_code, year, season_name):
    kamoku_name_for_folder = kamoku_code.upper()
    season_name_for_folder = {"春季": "Spring", "秋季": "Autumn", "特別": "Special"}.get(season_name, "Special")
    output_dir = f"./DL/{kamoku_name_for_folder}/{year}/{season_name_for_folder}"
    if not path.exists(output_dir):
        makedirs(output_dir)
    return output_dir


def dl_mondai(kamoku_code):
    kamoku_name = kamoku_codes[kamoku_code]

    for data in ids:
        year = data["filename_ids"][:4]
        season = data["filename_ids"][7]
        season_name = {"h": "春季", "a": "秋季", "o": "特別"}.get(season, "特別")

        # 午後の問題ファイルが存在するか確認するためのフラグ
        pm_exists = False

        for time_part in ["pm", "am"]: # 午後を先に処理するように変更
            # 午前I/II、午後I/IIのファイルがあるか確認
            for i in range(1, 3):
                new_time_part = f"{time_part}{i}"

                # 午前問題の場合、"ap" または "koudo" を使用
                am_code = "koudo" if kamoku_code != "ap" and time_part == "am" and i == 1 else kamoku_code

                # URLとファイル名を生成 (問題)
                new_url_qs = f"{base_url}{data['id']}/{data['filename_ids']}{am_code}_{new_time_part}_qs.pdf"
                # ファイル名に試験名を追加
                new_filename_qs = f"{kamoku_name}_{year}{season_name}_{new_time_part.upper()}_{filename_codes['qs']}.pdf"

                # URLとファイル名を生成 (解答)
                new_url_ans = f"{base_url}{data['id']}/{data['filename_ids']}{am_code}_{new_time_part}_ans.pdf"
                # ファイル名に試験名を追加
                new_filename_ans = f"{kamoku_name}_{year}{season_name}_{new_time_part.upper()}_{filename_codes['ans']}.pdf"

                # 午後の場合、問題ファイルが存在するか確認
                if time_part == "pm":
                    output_path_qs = new_filename_qs
                    if i == 1: # PM1 の場合のみ存在確認
                        if not path.exists(output_path_qs): # ファイルが存在しない場合のみダウンロードを試みる
                            if dl_file(new_url_qs, output_path_qs, kamoku_code, year, season_name):
                                pm_exists = True # 午後の問題が存在する場合、フラグを立てる
                                # 解答をダウンロード
                                output_path_ans = new_filename_ans
                                dl_file(new_url_ans, output_path_ans, kamoku_code, year, season_name)

                                # 採点講評のURLとファイル名を生成 (午後I/IIのみ)
                                if time_part == "pm":
                                    new_url_cmnt = f"{base_url}{data['id']}/{data['filename_ids']}{am_code}_{new_time_part}_cmnt.pdf"
                                    # ファイル名に試験名を追加
                                    new_filename_cmnt = f"{kamoku_name}_{year}{season_name}_{new_time_part.upper()}_{filename_codes['cmnt']}.pdf"
                                    output_path_cmnt = new_filename_cmnt
                                    dl_file(new_url_cmnt, output_path_cmnt, kamoku_code, year, season_name)
                            else:
                                # PM1 が存在しない場合、PM のみ存在するか確認
                                new_time_part_pm = "pm"
                                new_url_qs_pm = f"{base_url}{data['id']}/{data['filename_ids']}{kamoku_code}_{new_time_part_pm}_qs.pdf"
                                # ファイル名に試験名を追加
                                new_filename_qs_pm = f"{kamoku_name}_{year}{season_name}_{new_time_part_pm.upper()}_{filename_codes['qs']}.pdf"
                                output_path_qs_pm = new_filename_qs_pm
                                if not path.exists(output_path_qs_pm):
                                    if dl_file(new_url_qs_pm, output_path_qs_pm, kamoku_code, year, season_name):
                                        pm_exists = True
                                        new_url_ans_pm = f"{base_url}{data['id']}/{data['filename_ids']}{kamoku_code}_{new_time_part_pm}_ans.pdf"
                                        # ファイル名に試験名を追加
                                        new_filename_ans_pm = f"{kamoku_name}_{year}{season_name}_{new_time_part_pm.upper()}_{filename_codes['ans']}.pdf"
                                        output_path_ans_pm = new_filename_ans_pm
                                        dl_file(new_url_ans_pm, output_path_ans_pm, kamoku_code, year, season_name)
                                        new_url_cmnt_pm = f"{base_url}{data['id']}/{data['filename_ids']}{kamoku_code}_{new_time_part_pm}_cmnt.pdf"
                                        # ファイル名に試験名を追加
                                        new_filename_cmnt_pm = f"{kamoku_name}_{year}{season_name}_{new_time_part_pm.upper()}_{filename_codes['cmnt']}.pdf"
                                        output_path_cmnt_pm = new_filename_cmnt_pm
                                        dl_file(new_url_cmnt_pm, output_path_cmnt_pm, kamoku_code, year, season_name)
                                    else:
                                        print(f"{year}{season_name}の午後問題が存在しないため、午前のダウンロードをスキップします。")
                                        break # 午後が存在しない場合、午前のダウンロードをスキップ
                        else:
                            pm_exists = True # PM1 が存在する場合はフラグを立てる
                    elif pm_exists: # PM2 の場合、PM1 が存在する場合のみダウンロード
                        # PM2 の問題、解答、採点講評をダウンロード
                        output_path_qs = new_filename_qs
                        dl_file(new_url_qs, output_path_qs, kamoku_code, year, season_name)
                        output_path_ans = new_filename_ans
                        dl_file(new_url_ans, output_path_ans, kamoku_code, year, season_name)
                        if time_part == "pm":
                            new_url_cmnt = f"{base_url}{data['id']}/{data['filename_ids']}{am_code}_{new_time_part}_cmnt.pdf"
                            # ファイル名に試験名を追加
                            new_filename_cmnt = f"{kamoku_name}_{year}{season_name}_{new_time_part.upper()}_{filename_codes['cmnt']}.pdf"
                            output_path_cmnt = new_filename_cmnt
                            dl_file(new_url_cmnt, output_path_cmnt, kamoku_code, year, season_name)
                # 午前の場合、ダウンロードを実行
                elif time_part == "am" and pm_exists: # 午後が存在する場合のみ、午前をダウンロード
                    output_path_qs = new_filename_qs
                    if dl_file(new_url_qs, output_path_qs, kamoku_code, year, season_name):
                        # 解答をダウンロード
                        output_path_ans = new_filename_ans
                        dl_file(new_url_ans, output_path_ans, kamoku_code, year, season_name)

            # am/pm のファイルがないか確認
            if pm_exists: # 午後が存在する場合のみ、am/pmのファイルを確認
                for file_type_suffix in file_types[time_part]:
                    # 午前問題の場合、"ap" または "koudo" を使用
                    am_code = "koudo" if kamoku_code != "ap" and time_part == "am" else kamoku_code

                    # 過去問のURLを生成
                    url = f"{base_url}{data['id']}/{data['filename_ids']}{am_code}_{file_type_suffix}.pdf"

                    # ファイル名のパターンを決定
                    if file_type_suffix.endswith("_cmnt"):
                        filename_pattern_key = "cmnt"  # 採点講評の場合
                    else:
                        filename_pattern_key = file_type_suffix.split("_")[1]

                    # 保存するファイル名を生成
                    # ファイル名に試験名を追加
                    filename = f"{kamoku_name}_{year}{season_name}_{time_part.upper()}_{filename_codes[filename_pattern_key]}.pdf"
                    output_path = filename
                    dl_file(url, output_path, kamoku_code, year, season_name)

        if not pm_exists:
            print(f"{year}{season_name}の試験は存在しないため、フォルダを作成しません。")
            continue # 午後が存在しない場合、フォルダを作成しない

    print(f"{kamoku_name}のダウンロードが完了しました。")


# プログラムのエントリポイント
if __name__ == "__main__":
    while True:
        inp = input(
            "ダウンロードしたい試験区分のコードを小文字で入力してください（例：ap）：\n修了する場合はqを入力してください。"
        )
        if inp in kamoku_codes:
            dl_mondai(inp)
            break
        elif inp == "q":
            print("終了します。")
            exit()
        else:
            print("試験区分のコードを入力してください。")
# Out:
# ITストラテジスト試験_2024秋季_PM1_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2024秋季_PM_問題.pdf は見つかりませんでした。
# 2024秋季の午後問題が存在しないため、午前のダウンロードをスキップします。
# 2024秋季の試験は存在しないため、フォルダを作成しません。
# ITストラテジスト試験_2024春季_PM1_問題.pdf を保存しました。
# ITストラテジスト試験_2024春季_PM1_解答.pdf を保存しました。
# ITストラテジスト試験_2024春季_PM1_採点講評.pdf を保存しました。
# ITストラテジスト試験_2024春季_PM2_問題.pdf を保存しました。
# ITストラテジスト試験_2024春季_PM2_解答.pdf を保存しました。
# ITストラテジスト試験_2024春季_PM2_採点講評.pdf を保存しました。
# ITストラテジスト試験_2024春季_PM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2024春季_PM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2024春季_PM_採点講評.pdf は見つかりませんでした。
# ITストラテジスト試験_2024春季_AM1_問題.pdf を保存しました。
# ITストラテジスト試験_2024春季_AM1_解答.pdf を保存しました。
# ITストラテジスト試験_2024春季_AM2_問題.pdf を保存しました。
# ITストラテジスト試験_2024春季_AM2_解答.pdf を保存しました。
# ITストラテジスト試験_2024春季_AM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2024春季_AM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2023秋季_PM1_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2023秋季_PM_問題.pdf は見つかりませんでした。
# 2023秋季の午後問題が存在しないため、午前のダウンロードをスキップします。
# 2023秋季の試験は存在しないため、フォルダを作成しません。
# ITストラテジスト試験_2023春季_PM1_問題.pdf を保存しました。
# ITストラテジスト試験_2023春季_PM1_解答.pdf を保存しました。
# ITストラテジスト試験_2023春季_PM1_採点講評.pdf を保存しました。
# ITストラテジスト試験_2023春季_PM2_問題.pdf を保存しました。
# ITストラテジスト試験_2023春季_PM2_解答.pdf を保存しました。
# ITストラテジスト試験_2023春季_PM2_採点講評.pdf を保存しました。
# ITストラテジスト試験_2023春季_PM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2023春季_PM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2023春季_PM_採点講評.pdf は見つかりませんでした。
# ITストラテジスト試験_2023春季_AM1_問題.pdf を保存しました。
# ITストラテジスト試験_2023春季_AM1_解答.pdf を保存しました。
# ITストラテジスト試験_2023春季_AM2_問題.pdf を保存しました。
# ITストラテジスト試験_2023春季_AM2_解答.pdf を保存しました。
# ITストラテジスト試験_2023春季_AM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2023春季_AM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2022秋季_PM1_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2022秋季_PM_問題.pdf は見つかりませんでした。
# 2022秋季の午後問題が存在しないため、午前のダウンロードをスキップします。
# 2022秋季の試験は存在しないため、フォルダを作成しません。
# ITストラテジスト試験_2022春季_PM1_問題.pdf を保存しました。
# ITストラテジスト試験_2022春季_PM1_解答.pdf を保存しました。
# ITストラテジスト試験_2022春季_PM1_採点講評.pdf を保存しました。
# ITストラテジスト試験_2022春季_PM2_問題.pdf を保存しました。
# ITストラテジスト試験_2022春季_PM2_解答.pdf を保存しました。
# ITストラテジスト試験_2022春季_PM2_採点講評.pdf を保存しました。
# ITストラテジスト試験_2022春季_PM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2022春季_PM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2022春季_PM_採点講評.pdf は見つかりませんでした。
# ITストラテジスト試験_2022春季_AM1_問題.pdf を保存しました。
# ITストラテジスト試験_2022春季_AM1_解答.pdf を保存しました。
# ITストラテジスト試験_2022春季_AM2_問題.pdf を保存しました。
# ITストラテジスト試験_2022春季_AM2_解答.pdf を保存しました。
# ITストラテジスト試験_2022春季_AM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2022春季_AM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2021秋季_PM1_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2021秋季_PM_問題.pdf は見つかりませんでした。
# 2021秋季の午後問題が存在しないため、午前のダウンロードをスキップします。
# 2021秋季の試験は存在しないため、フォルダを作成しません。
# ITストラテジスト試験_2021春季_PM1_問題.pdf を保存しました。
# ITストラテジスト試験_2021春季_PM1_解答.pdf を保存しました。
# ITストラテジスト試験_2021春季_PM1_採点講評.pdf を保存しました。
# ITストラテジスト試験_2021春季_PM2_問題.pdf を保存しました。
# ITストラテジスト試験_2021春季_PM2_解答.pdf を保存しました。
# ITストラテジスト試験_2021春季_PM2_採点講評.pdf を保存しました。
# ITストラテジスト試験_2021春季_PM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2021春季_PM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2021春季_PM_採点講評.pdf は見つかりませんでした。
# ITストラテジスト試験_2021春季_AM1_問題.pdf を保存しました。
# ITストラテジスト試験_2021春季_AM1_解答.pdf を保存しました。
# ITストラテジスト試験_2021春季_AM2_問題.pdf を保存しました。
# ITストラテジスト試験_2021春季_AM2_解答.pdf を保存しました。
# ITストラテジスト試験_2021春季_AM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2021春季_AM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2020特別_PM1_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2020特別_PM_問題.pdf は見つかりませんでした。
# 2020特別の午後問題が存在しないため、午前のダウンロードをスキップします。
# 2020特別の試験は存在しないため、フォルダを作成しません。
# ITストラテジスト試験_2019秋季_PM1_問題.pdf を保存しました。
# ITストラテジスト試験_2019秋季_PM1_解答.pdf を保存しました。
# ITストラテジスト試験_2019秋季_PM1_採点講評.pdf を保存しました。
# ITストラテジスト試験_2019秋季_PM2_問題.pdf を保存しました。
# ITストラテジスト試験_2019秋季_PM2_解答.pdf を保存しました。
# ITストラテジスト試験_2019秋季_PM2_採点講評.pdf を保存しました。
# ITストラテジスト試験_2019秋季_PM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2019秋季_PM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2019秋季_PM_採点講評.pdf は見つかりませんでした。
# ITストラテジスト試験_2019秋季_AM1_問題.pdf を保存しました。
# ITストラテジスト試験_2019秋季_AM1_解答.pdf を保存しました。
# ITストラテジスト試験_2019秋季_AM2_問題.pdf を保存しました。
# ITストラテジスト試験_2019秋季_AM2_解答.pdf を保存しました。
# ITストラテジスト試験_2019秋季_AM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2019秋季_AM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2019春季_PM1_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2019春季_PM_問題.pdf は見つかりませんでした。
# 2019春季の午後問題が存在しないため、午前のダウンロードをスキップします。
# 2019春季の試験は存在しないため、フォルダを作成しません。
# ITストラテジスト試験_2018秋季_PM1_問題.pdf を保存しました。
# ITストラテジスト試験_2018秋季_PM1_解答.pdf を保存しました。
# ITストラテジスト試験_2018秋季_PM1_採点講評.pdf を保存しました。
# ITストラテジスト試験_2018秋季_PM2_問題.pdf を保存しました。
# ITストラテジスト試験_2018秋季_PM2_解答.pdf を保存しました。
# ITストラテジスト試験_2018秋季_PM2_採点講評.pdf を保存しました。
# ITストラテジスト試験_2018秋季_PM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2018秋季_PM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2018秋季_PM_採点講評.pdf は見つかりませんでした。
# ITストラテジスト試験_2018秋季_AM1_問題.pdf を保存しました。
# ITストラテジスト試験_2018秋季_AM1_解答.pdf を保存しました。
# ITストラテジスト試験_2018秋季_AM2_問題.pdf を保存しました。
# ITストラテジスト試験_2018秋季_AM2_解答.pdf を保存しました。
# ITストラテジスト試験_2018秋季_AM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2018秋季_AM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2018春季_PM1_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2018春季_PM_問題.pdf は見つかりませんでした。
# 2018春季の午後問題が存在しないため、午前のダウンロードをスキップします。
# 2018春季の試験は存在しないため、フォルダを作成しません。
# ITストラテジスト試験_2017秋季_PM1_問題.pdf を保存しました。
# ITストラテジスト試験_2017秋季_PM1_解答.pdf を保存しました。
# ITストラテジスト試験_2017秋季_PM1_採点講評.pdf を保存しました。
# ITストラテジスト試験_2017秋季_PM2_問題.pdf を保存しました。
# ITストラテジスト試験_2017秋季_PM2_解答.pdf を保存しました。
# ITストラテジスト試験_2017秋季_PM2_採点講評.pdf を保存しました。
# ITストラテジスト試験_2017秋季_PM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2017秋季_PM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2017秋季_PM_採点講評.pdf は見つかりませんでした。
# ITストラテジスト試験_2017秋季_AM1_問題.pdf を保存しました。
# ITストラテジスト試験_2017秋季_AM1_解答.pdf を保存しました。
# ITストラテジスト試験_2017秋季_AM2_問題.pdf を保存しました。
# ITストラテジスト試験_2017秋季_AM2_解答.pdf を保存しました。
# ITストラテジスト試験_2017秋季_AM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2017秋季_AM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2017春季_PM1_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2017春季_PM_問題.pdf は見つかりませんでした。
# 2017春季の午後問題が存在しないため、午前のダウンロードをスキップします。
# 2017春季の試験は存在しないため、フォルダを作成しません。
# ITストラテジスト試験_2016秋季_PM1_問題.pdf を保存しました。
# ITストラテジスト試験_2016秋季_PM1_解答.pdf を保存しました。
# ITストラテジスト試験_2016秋季_PM1_採点講評.pdf を保存しました。
# ITストラテジスト試験_2016秋季_PM2_問題.pdf を保存しました。
# ITストラテジスト試験_2016秋季_PM2_解答.pdf を保存しました。
# ITストラテジスト試験_2016秋季_PM2_採点講評.pdf を保存しました。
# ITストラテジスト試験_2016秋季_PM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2016秋季_PM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2016秋季_PM_採点講評.pdf は見つかりませんでした。
# ITストラテジスト試験_2016秋季_AM1_問題.pdf を保存しました。
# ITストラテジスト試験_2016秋季_AM1_解答.pdf を保存しました。
# ITストラテジスト試験_2016秋季_AM2_問題.pdf を保存しました。
# ITストラテジスト試験_2016秋季_AM2_解答.pdf を保存しました。
# ITストラテジスト試験_2016秋季_AM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2016秋季_AM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2016春季_PM1_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2016春季_PM_問題.pdf は見つかりませんでした。
# 2016春季の午後問題が存在しないため、午前のダウンロードをスキップします。
# 2016春季の試験は存在しないため、フォルダを作成しません。
# ITストラテジスト試験_2015秋季_PM1_問題.pdf を保存しました。
# ITストラテジスト試験_2015秋季_PM1_解答.pdf を保存しました。
# ITストラテジスト試験_2015秋季_PM1_採点講評.pdf を保存しました。
# ITストラテジスト試験_2015秋季_PM2_問題.pdf を保存しました。
# ITストラテジスト試験_2015秋季_PM2_解答.pdf を保存しました。
# ITストラテジスト試験_2015秋季_PM2_採点講評.pdf を保存しました。
# ITストラテジスト試験_2015秋季_PM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2015秋季_PM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2015秋季_PM_採点講評.pdf は見つかりませんでした。
# ITストラテジスト試験_2015秋季_AM1_問題.pdf を保存しました。
# ITストラテジスト試験_2015秋季_AM1_解答.pdf を保存しました。
# ITストラテジスト試験_2015秋季_AM2_問題.pdf を保存しました。
# ITストラテジスト試験_2015秋季_AM2_解答.pdf を保存しました。
# ITストラテジスト試験_2015秋季_AM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2015秋季_AM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2015春季_PM1_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2015春季_PM_問題.pdf は見つかりませんでした。
# 2015春季の午後問題が存在しないため、午前のダウンロードをスキップします。
# 2015春季の試験は存在しないため、フォルダを作成しません。
# ITストラテジスト試験_2014秋季_PM1_問題.pdf を保存しました。
# ITストラテジスト試験_2014秋季_PM1_解答.pdf を保存しました。
# ITストラテジスト試験_2014秋季_PM1_採点講評.pdf を保存しました。
# ITストラテジスト試験_2014秋季_PM2_問題.pdf を保存しました。
# ITストラテジスト試験_2014秋季_PM2_解答.pdf を保存しました。
# ITストラテジスト試験_2014秋季_PM2_採点講評.pdf を保存しました。
# ITストラテジスト試験_2014秋季_PM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2014秋季_PM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2014秋季_PM_採点講評.pdf は見つかりませんでした。
# ITストラテジスト試験_2014秋季_AM1_問題.pdf を保存しました。
# ITストラテジスト試験_2014秋季_AM1_解答.pdf を保存しました。
# ITストラテジスト試験_2014秋季_AM2_問題.pdf を保存しました。
# ITストラテジスト試験_2014秋季_AM2_解答.pdf を保存しました。
# ITストラテジスト試験_2014秋季_AM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2014秋季_AM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2014春季_PM1_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2014春季_PM_問題.pdf は見つかりませんでした。
# 2014春季の午後問題が存在しないため、午前のダウンロードをスキップします。
# 2014春季の試験は存在しないため、フォルダを作成しません。
# ITストラテジスト試験_2013秋季_PM1_問題.pdf を保存しました。
# ITストラテジスト試験_2013秋季_PM1_解答.pdf を保存しました。
# ITストラテジスト試験_2013秋季_PM1_採点講評.pdf を保存しました。
# ITストラテジスト試験_2013秋季_PM2_問題.pdf を保存しました。
# ITストラテジスト試験_2013秋季_PM2_解答.pdf を保存しました。
# ITストラテジスト試験_2013秋季_PM2_採点講評.pdf を保存しました。
# ITストラテジスト試験_2013秋季_PM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2013秋季_PM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2013秋季_PM_採点講評.pdf は見つかりませんでした。
# ITストラテジスト試験_2013秋季_AM1_問題.pdf を保存しました。
# ITストラテジスト試験_2013秋季_AM1_解答.pdf を保存しました。
# ITストラテジスト試験_2013秋季_AM2_問題.pdf を保存しました。
# ITストラテジスト試験_2013秋季_AM2_解答.pdf を保存しました。
# ITストラテジスト試験_2013秋季_AM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2013秋季_AM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2013春季_PM1_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2013春季_PM_問題.pdf は見つかりませんでした。
# 2013春季の午後問題が存在しないため、午前のダウンロードをスキップします。
# 2013春季の試験は存在しないため、フォルダを作成しません。
# ITストラテジスト試験_2012秋季_PM1_問題.pdf を保存しました。
# ITストラテジスト試験_2012秋季_PM1_解答.pdf を保存しました。
# ITストラテジスト試験_2012秋季_PM1_採点講評.pdf を保存しました。
# ITストラテジスト試験_2012秋季_PM2_問題.pdf を保存しました。
# ITストラテジスト試験_2012秋季_PM2_解答.pdf を保存しました。
# ITストラテジスト試験_2012秋季_PM2_採点講評.pdf を保存しました。
# ITストラテジスト試験_2012秋季_PM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2012秋季_PM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2012秋季_PM_採点講評.pdf は見つかりませんでした。
# ITストラテジスト試験_2012秋季_AM1_問題.pdf を保存しました。
# ITストラテジスト試験_2012秋季_AM1_解答.pdf を保存しました。
# ITストラテジスト試験_2012秋季_AM2_問題.pdf を保存しました。
# ITストラテジスト試験_2012秋季_AM2_解答.pdf を保存しました。
# ITストラテジスト試験_2012秋季_AM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2012秋季_AM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2012春季_PM1_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2012春季_PM_問題.pdf は見つかりませんでした。
# 2012春季の午後問題が存在しないため、午前のダウンロードをスキップします。
# 2012春季の試験は存在しないため、フォルダを作成しません。
# ITストラテジスト試験_2011秋季_PM1_問題.pdf を保存しました。
# ITストラテジスト試験_2011秋季_PM1_解答.pdf を保存しました。
# ITストラテジスト試験_2011秋季_PM1_採点講評.pdf を保存しました。
# ITストラテジスト試験_2011秋季_PM2_問題.pdf を保存しました。
# ITストラテジスト試験_2011秋季_PM2_解答.pdf を保存しました。
# ITストラテジスト試験_2011秋季_PM2_採点講評.pdf を保存しました。
# ITストラテジスト試験_2011秋季_PM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2011秋季_PM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2011秋季_PM_採点講評.pdf は見つかりませんでした。
# ITストラテジスト試験_2011秋季_AM1_問題.pdf を保存しました。
# ITストラテジスト試験_2011秋季_AM1_解答.pdf を保存しました。
# ITストラテジスト試験_2011秋季_AM2_問題.pdf を保存しました。
# ITストラテジスト試験_2011秋季_AM2_解答.pdf を保存しました。
# ITストラテジスト試験_2011秋季_AM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2011秋季_AM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2011特別_PM1_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2011特別_PM_問題.pdf は見つかりませんでした。
# 2011特別の午後問題が存在しないため、午前のダウンロードをスキップします。
# 2011特別の試験は存在しないため、フォルダを作成しません。
# ITストラテジスト試験_2010秋季_PM1_問題.pdf を保存しました。
# ITストラテジスト試験_2010秋季_PM1_解答.pdf を保存しました。
# ITストラテジスト試験_2010秋季_PM1_採点講評.pdf を保存しました。
# ITストラテジスト試験_2010秋季_PM2_問題.pdf を保存しました。
# ITストラテジスト試験_2010秋季_PM2_解答.pdf を保存しました。
# ITストラテジスト試験_2010秋季_PM2_採点講評.pdf を保存しました。
# ITストラテジスト試験_2010秋季_PM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2010秋季_PM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2010秋季_PM_採点講評.pdf は見つかりませんでした。
# ITストラテジスト試験_2010秋季_AM1_問題.pdf を保存しました。
# ITストラテジスト試験_2010秋季_AM1_解答.pdf を保存しました。
# ITストラテジスト試験_2010秋季_AM2_問題.pdf を保存しました。
# ITストラテジスト試験_2010秋季_AM2_解答.pdf を保存しました。
# ITストラテジスト試験_2010秋季_AM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2010秋季_AM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2010春季_PM1_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2010春季_PM_問題.pdf は見つかりませんでした。
# 2010春季の午後問題が存在しないため、午前のダウンロードをスキップします。
# 2010春季の試験は存在しないため、フォルダを作成しません。
# ITストラテジスト試験_2009秋季_PM1_問題.pdf を保存しました。
# ITストラテジスト試験_2009秋季_PM1_解答.pdf を保存しました。
# ITストラテジスト試験_2009秋季_PM1_採点講評.pdf を保存しました。
# ITストラテジスト試験_2009秋季_PM2_問題.pdf を保存しました。
# ITストラテジスト試験_2009秋季_PM2_解答.pdf を保存しました。
# ITストラテジスト試験_2009秋季_PM2_採点講評.pdf を保存しました。
# ITストラテジスト試験_2009秋季_PM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2009秋季_PM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2009秋季_PM_採点講評.pdf は見つかりませんでした。
# ITストラテジスト試験_2009秋季_AM1_問題.pdf を保存しました。
# ITストラテジスト試験_2009秋季_AM1_解答.pdf を保存しました。
# ITストラテジスト試験_2009秋季_AM2_問題.pdf を保存しました。
# ITストラテジスト試験_2009秋季_AM2_解答.pdf を保存しました。
# ITストラテジスト試験_2009秋季_AM_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2009秋季_AM_解答.pdf は見つかりませんでした。
# ITストラテジスト試験_2009春季_PM1_問題.pdf は見つかりませんでした。
# ITストラテジスト試験_2009春季_PM_問題.pdf は見つかりませんでした。
# 2009春季の午後問題が存在しないため、午前のダウンロードをスキップします。
# 2009春季の試験は存在しないため、フォルダを作成しません。
# ITストラテジスト試験のダウンロードが完了しました。

# %% [markdown]
# 読み取り
# https://qiita.com/kccs_hiroshi-tatsuwaki/items/f3277a157acf965c33e8

# %% [markdown]
# # PDF→画像部

# %% [markdown]
# ## ルート１：pdf2imageで分割

# %%
import os
import shutil
import tempfile
from os import makedirs, path
from time import sleep
from urllib.request import urlretrieve
import subprocess
from pdf2image import convert_from_path

# PDFを画像に変換する関数
def convert_pdf_to_image(pdf_path, output_dir_path):
    os.makedirs(output_dir_path, exist_ok=True)

    images = convert_from_path(pdf_path)
    for i, image in enumerate(images):
        output_path = f"{output_dir_path}/page_{i + 1}.png"
        image.save(output_path, "PNG")
        print(f"Saved: {output_path}")

# ダウンロードしたPDFを画像に変換する処理
def process_pdfs():
    dl_dir = "./DL"
    png_dir = "./PNG"
    os.makedirs(png_dir, exist_ok=True)

    for root, dirs, files in os.walk(dl_dir):
        for file in files:
            if file.lower().endswith(".pdf"):
                pdf_path = os.path.join(root, file)
                # 出力先のディレクトリを作成
                relative_path = os.path.relpath(root, dl_dir)
                output_base_dir = os.path.join(png_dir, relative_path)
                
                # ファイル名から拡張子を除いた部分を取得
                file_name_without_ext = os.path.splitext(file)[0]
                
                # ファイル名からフォルダ名を生成する関数
                def generate_folder_name(file_name):
                    parts = file_name.split('_')
                    if len(parts) < 3:
                        return file_name  # ファイル名が想定外の場合はそのまま返す
                    
                    kamoku_name = parts[0]
                    year_season = parts[1]
                    time_part = parts[2]
                    
                    kamoku_code = ""
                    for code, name in kamoku_codes.items():
                        if name == kamoku_name:
                            kamoku_code = code.upper()
                            break
                    
                    year = year_season[:4]
                    season = year_season[4:6]
                    season_code = {"春季": "S", "秋季": "A", "特別": "X"}.get(season, "X")
                    
                    time_part_code = time_part.replace("午前", "AM").replace("午後", "PM").replace("解答","Ans").replace("問題","Qs").replace("採点講評","Cmnt")
                    
                    return f"{kamoku_code}_{year}{season_code}_{time_part_code}"

                # ファイル名からフォルダ名を生成
                output_dir_name = generate_folder_name(file_name_without_ext)
                
                # ファイル名と同じ名前のフォルダを最下層に作成
                output_dir = os.path.join(output_base_dir, output_dir_name)

                # フォルダが存在するか確認
                if os.path.exists(output_dir):
                    print(f"{output_dir} は既に存在するため、変換をスキップします。")
                    continue
                
                os.makedirs(output_dir, exist_ok=True)
                convert_pdf_to_image(pdf_path, output_dir)
                print(f"{pdf_path} の変換が完了しました。") 

    print("全てのPDFファイルの変換が完了しました。")

if __name__ == "__main__":
    process_pdfs()
    process_images()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 79
#      76     print("全てのPDFファイルの変換が完了しました。")
#      78 if __name__ == "__main__":
# ---> 79     process_pdfs()
#      80     process_images()
#
# Cell In[2], line 62, in process_pdfs()
#      59     return f"{kamoku_code}_{year}{season_code}_{time_part_code}"
#      61 # ファイル名からフォルダ名を生成
# ---> 62 output_dir_name = generate_folder_name(file_name_without_ext)
#      64 # ファイル名と同じ名前のフォルダを最下層に作成
#      65 output_dir = os.path.join(output_base_dir, output_dir_name)
#
# Cell In[2], line 48, in process_pdfs.<locals>.generate_folder_name(file_name)
#      45 time_part = parts[2]
#      47 kamoku_code = ""
# ---> 48 for code, name in kamoku_codes.items():
#      49     if name == kamoku_name:
#      50         kamoku_code = code.upper()
#
# NameError: name 'kamoku_codes' is not defined

# %% [markdown]
# ## ルート2:PyMuPDF

# %%
# !pip install pymupdf
# Out:
# Collecting pymupdf
#   Downloading pymupdf-1.25.1-cp39-abi3-win_amd64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.25.1-cp39-abi3-win_amd64.whl (16.6 MB)
#    ---------------------------------------- 0.0/16.6 MB ? eta -:--:--
#    ------------ --------------------------- 5.2/16.6 MB 31.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 9.4/16.6 MB 24.5 MB/s eta 0:00:01
#    ------------------------------- -------- 13.1/16.6 MB 22.2 MB/s eta 0:00:01
#    ---------------------------------------  16.5/16.6 MB 21.7 MB/s eta 0:00:01
#    ---------------------------------------- 16.6/16.6 MB 20.0 MB/s eta 0:00:00
# Installing collected packages: pymupdf
# Successfully installed pymupdf-1.25.1
# WARNING: Ignoring invalid distribution ~ip (I:\資料\KIC\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (I:\資料\KIC\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (I:\資料\KIC\.venv\Lib\site-packages)

# %% [markdown]
# # yomitoku部

# %% [markdown]
# ## yomitoku[GPU]環境整備部
# ローカル動作の為に環境整備しているため、動作環境に合わせて変更の必要あり。
# yomitoku[GPU]動作環境：pytorch は 2.5 以上のバージョンに対応しています。その関係で CUDA11.8 以上
#
# 今回はpytorch2.5,cuda12.4（を導入済みPCにて指定先だけ変更）

# %%
# !pip install torch==2.5.0 torchvision==0.20.0 torchaudio==2.5.0 --index-url https://download.pytorch.org/whl/cu124
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu124
# Requirement already satisfied: torch==2.5.0 in i:\資料\kic\.venv\lib\site-packages (2.5.0+cu124)
# Requirement already satisfied: torchvision==0.20.0 in i:\資料\kic\.venv\lib\site-packages (0.20.0+cu124)
# Requirement already satisfied: torchaudio==2.5.0 in i:\資料\kic\.venv\lib\site-packages (2.5.0+cu124)
# Requirement already satisfied: filelock in i:\資料\kic\.venv\lib\site-packages (from torch==2.5.0) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in i:\資料\kic\.venv\lib\site-packages (from torch==2.5.0) (4.12.2)
# Requirement already satisfied: networkx in i:\資料\kic\.venv\lib\site-packages (from torch==2.5.0) (3.4.2)
# Requirement already satisfied: jinja2 in i:\資料\kic\.venv\lib\site-packages (from torch==2.5.0) (3.1.5)
# Requirement already satisfied: fsspec in i:\資料\kic\.venv\lib\site-packages (from torch==2.5.0) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in i:\資料\kic\.venv\lib\site-packages (from torch==2.5.0) (1.13.1)
# Requirement already satisfied: numpy in i:\資料\kic\.venv\lib\site-packages (from torchvision==0.20.0) (2.2.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in i:\資料\kic\.venv\lib\site-packages (from torchvision==0.20.0) (11.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in i:\資料\kic\.venv\lib\site-packages (from sympy==1.13.1->torch==2.5.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in i:\資料\kic\.venv\lib\site-packages (from jinja2->torch==2.5.0) (3.0.2)
# WARNING: Ignoring invalid distribution ~ip (I:\資料\KIC\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (I:\資料\KIC\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (I:\資料\KIC\.venv\Lib\site-packages)

# %%
# !set CUDA_PATH=C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.4
# !set PATH=%CUDA_PATH%\bin;%CUDA_PATH%\libnvvp;%PATH%
# !set CUDA_VISIBLE_DEVICES=0 # 複数のGPUがある場合には使うGPUを選択

# %%
import torch
print(torch.cuda.is_available())
print(torch.version.cuda)

# !nvidia-smi
# Out:
# True
# 12.4
# Wed Jan  8 08:27:22 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 565.90                 Driver Version: 565.90         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4080      WDDM  |   00000000:2B:00.0  On |                  N/A |
# |  0%   52C    P0             55W /  320W |    1960MiB /  16376MiB |      6%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      2088    C+G   ...B\system_tray\lghub_system_tray.exe      N/A      |
# |    0   N/A  N/A      2908    C+G   ...ograms\cron-web\Notion Calendar.exe      N/A      |
# |    0   N/A  N/A      3184    C+G   ...nt.CBS_cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A      4644    C+G   C:\Windows\System32\ShellHost.exe           N/A      |
# |    0   N/A  N/A     10576    C+G   ...3d8bbwe\dotnet\PAD.Console.Host.exe      N/A      |
# |    0   N/A  N/A     10860    C+G   C:\Windows\explorer.exe                     N/A      |
# |    0   N/A  N/A     10916    C+G   ...al\Discord\app-1.0.9177\Discord.exe      N/A      |
# |    0   N/A  N/A     12028    C+G   ...2txyewy\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A     12048    C+G   ...es (x86)\Dropbox\Client\Dropbox.exe      N/A      |
# |    0   N/A  N/A     12896    C+G   ...es (x86)\Dropbox\Client\Dropbox.exe      N/A      |
# |    0   N/A  N/A     16448    C+G   ...crosoft\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A     16620    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A     17116    C+G   ...crosoft\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A     20688    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A     21092    C+G   ...AppData\Roaming\Spotify\Spotify.exe      N/A      |
# |    0   N/A  N/A     22516    C+G   ...ogram Files\Bitwarden\Bitwarden.exe      N/A      |
# |    0   N/A  N/A     24332    C+G   ...5n1h2txyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A     26652    C+G   ...ys\WinUI3Apps\PowerToys.Peek.UI.exe      N/A      |
# |    0   N/A  N/A     26756    C+G   ...werToys\PowerToys.PowerLauncher.exe      N/A      |
# |    0   N/A  N/A     27500    C+G   ...GeForce Experience\NVIDIA Share.exe      N/A      |
# |    0   N/A  N/A     28956    C+G   ....0_x64__kzh8wxbdkxb8p\DCv2\DCv2.exe      N/A      |
# |    0   N/A  N/A     29712    C+G   ...aam7r\AcrobatNotificationClient.exe      N/A      |
# |    0   N/A  N/A     31328    C+G   ... Stream\101.0.3.0\GoogleDriveFS.exe      N/A      |
# |    0   N/A  N/A     32588    C+G   ...ogram Files\Rainmeter\Rainmeter.exe      N/A      |
# |    0   N/A  N/A     32736    C+G   ...\Local\slack\app-4.41.105\slack.exe      N/A      |
# |    0   N/A  N/A     32872    C+G   H:\GOG Galaxy\GalaxyClient Helper.exe       N/A      |
# |    0   N/A  N/A     33656    C+G   ...\Local\slack\app-4.41.105\slack.exe      N/A      |
# |    0   N/A  N/A     35500    C+G   ...on\HEX\Creative Cloud UI Helper.exe      N/A      |
# |    0   N/A  N/A     36620    C+G   ...\TrueImageHome\TrueImageMonitor.exe      N/A      |
# |    0   N/A  N/A     37116    C+G   ...ejd91yc\AdobeNotificationClient.exe      N/A      |
# |    0   N/A  N/A     39444    C+G   C:\Windows\explorer.exe                     N/A      |
# |    0   N/A  N/A     40700    C+G   ...ta\Local\Programs\cursor\Cursor.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## yomitokuインストールと実行

# %%
# !pip install yomitoku[gpu]
# Out:
# Requirement already satisfied: yomitoku[gpu] in i:\資料\kic\.venv\lib\site-packages (0.7.1)
# Requirement already satisfied: huggingface-hub>=0.26.1 in i:\資料\kic\.venv\lib\site-packages (from yomitoku[gpu]) (0.27.1)
# Requirement already satisfied: lxml>=5.3.0 in i:\資料\kic\.venv\lib\site-packages (from yomitoku[gpu]) (5.3.0)
# Requirement already satisfied: omegaconf>=2.3.0 in i:\資料\kic\.venv\lib\site-packages (from yomitoku[gpu]) (2.3.0)
# Requirement already satisfied: onnx>=1.17.0 in i:\資料\kic\.venv\lib\site-packages (from yomitoku[gpu]) (1.17.0)
# Requirement already satisfied: onnxruntime>=1.20.1 in i:\資料\kic\.venv\lib\site-packages (from yomitoku[gpu]) (1.20.1)
# Requirement already satisfied: opencv-python>=4.10.0.84 in i:\資料\kic\.venv\lib\site-packages (from yomitoku[gpu]) (4.10.0.84)
# Requirement already satisfied: pyclipper>=1.3.0.post6 in i:\資料\kic\.venv\lib\site-packages (from yomitoku[gpu]) (1.3.0.post6)
# Requirement already satisfied: pydantic>=2.9.2 in i:\資料\kic\.venv\lib\site-packages (from yomitoku[gpu]) (2.10.4)
# Requirement already satisfied: pypdfium2>=4.30.0 in i:\資料\kic\.venv\lib\site-packages (from yomitoku[gpu]) (4.30.1)
# Requirement already satisfied: shapely>=2.0.6 in i:\資料\kic\.venv\lib\site-packages (from yomitoku[gpu]) (2.0.6)
# Requirement already satisfied: timm>=1.0.11 in i:\資料\kic\.venv\lib\site-packages (from yomitoku[gpu]) (1.0.12)
# Requirement already satisfied: torch>=2.5.0 in i:\資料\kic\.venv\lib\site-packages (from yomitoku[gpu]) (2.5.0+cu124)
# Requirement already satisfied: torchvision>=0.20.0 in i:\資料\kic\.venv\lib\site-packages (from yomitoku[gpu]) (0.20.0+cu124)
# Collecting onnxruntime-gpu>=1.20.1 (from yomitoku[gpu])
#   Downloading onnxruntime_gpu-1.20.1-cp311-cp311-win_amd64.whl.metadata (4.7 kB)
# Requirement already satisfied: filelock in i:\資料\kic\.venv\lib\site-packages (from huggingface-hub>=0.26.1->yomitoku[gpu]) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in i:\資料\kic\.venv\lib\site-packages (from huggingface-hub>=0.26.1->yomitoku[gpu]) (2024.12.0)
# Requirement already satisfied: packaging>=20.9 in i:\資料\kic\.venv\lib\site-packages (from huggingface-hub>=0.26.1->yomitoku[gpu]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in i:\資料\kic\.venv\lib\site-packages (from huggingface-hub>=0.26.1->yomitoku[gpu]) (6.0.2)
# Requirement already satisfied: requests in i:\資料\kic\.venv\lib\site-packages (from huggingface-hub>=0.26.1->yomitoku[gpu]) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in i:\資料\kic\.venv\lib\site-packages (from huggingface-hub>=0.26.1->yomitoku[gpu]) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in i:\資料\kic\.venv\lib\site-packages (from huggingface-hub>=0.26.1->yomitoku[gpu]) (4.12.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in i:\資料\kic\.venv\lib\site-packages (from omegaconf>=2.3.0->yomitoku[gpu]) (4.9.3)
# Requirement already satisfied: numpy>=1.20 in i:\資料\kic\.venv\lib\site-packages (from onnx>=1.17.0->yomitoku[gpu]) (2.2.1)
# Requirement already satisfied: protobuf>=3.20.2 in i:\資料\kic\.venv\lib\site-packages (from onnx>=1.17.0->yomitoku[gpu]) (5.29.2)
# Requirement already satisfied: coloredlogs in i:\資料\kic\.venv\lib\site-packages (from onnxruntime>=1.20.1->yomitoku[gpu]) (15.0.1)
# Requirement already satisfied: flatbuffers in i:\資料\kic\.venv\lib\site-packages (from onnxruntime>=1.20.1->yomitoku[gpu]) (24.12.23)
# Requirement already satisfied: sympy in i:\資料\kic\.venv\lib\site-packages (from onnxruntime>=1.20.1->yomitoku[gpu]) (1.13.1)
# Requirement already satisfied: annotated-types>=0.6.0 in i:\資料\kic\.venv\lib\site-packages (from pydantic>=2.9.2->yomitoku[gpu]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in i:\資料\kic\.venv\lib\site-packages (from pydantic>=2.9.2->yomitoku[gpu]) (2.27.2)
# Requirement already satisfied: safetensors in i:\資料\kic\.venv\lib\site-packages (from timm>=1.0.11->yomitoku[gpu]) (0.5.0)
# Requirement already satisfied: networkx in i:\資料\kic\.venv\lib\site-packages (from torch>=2.5.0->yomitoku[gpu]) (3.4.2)
# Requirement already satisfied: jinja2 in i:\資料\kic\.venv\lib\site-packages (from torch>=2.5.0->yomitoku[gpu]) (3.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in i:\資料\kic\.venv\lib\site-packages (from sympy->onnxruntime>=1.20.1->yomitoku[gpu]) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in i:\資料\kic\.venv\lib\site-packages (from torchvision>=0.20.0->yomitoku[gpu]) (11.1.0)
# Requirement already satisfied: colorama in i:\資料\kic\.venv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.26.1->yomitoku[gpu]) (0.4.6)
# Requirement already satisfied: humanfriendly>=9.1 in i:\資料\kic\.venv\lib\site-packages (from coloredlogs->onnxruntime>=1.20.1->yomitoku[gpu]) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in i:\資料\kic\.venv\lib\site-packages (from jinja2->torch>=2.5.0->yomitoku[gpu]) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in i:\資料\kic\.venv\lib\site-packages (from requests->huggingface-hub>=0.26.1->yomitoku[gpu]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in i:\資料\kic\.venv\lib\site-packages (from requests->huggingface-hub>=0.26.1->yomitoku[gpu]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in i:\資料\kic\.venv\lib\site-packages (from requests->huggingface-hub>=0.26.1->yomitoku[gpu]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in i:\資料\kic\.venv\lib\site-packages (from requests->huggingface-hub>=0.26.1->yomitoku[gpu]) (2024.12.14)
# Requirement already satisfied: pyreadline3 in i:\資料\kic\.venv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.20.1->yomitoku[gpu]) (3.5.4)
# Downloading onnxruntime_gpu-1.20.1-cp311-cp311-win_amd64.whl (279.7 MB)
#    ---------------------------------------- 0.0/279.7 MB ? eta -:--:--
#     --------------------------------------- 4.7/279.7 MB 28.6 MB/s eta 0:00:10
#    - -------------------------------------- 11.3/279.7 MB 29.4 MB/s eta 0:00:10
#    -- ------------------------------------- 17.6/279.7 MB 29.9 MB/s eta 0:00:09
#    --- ------------------------------------ 23.6/279.7 MB 29.9 MB/s eta 0:00:09
#    --- ------------------------------------ 27.3/279.7 MB 29.8 MB/s eta 0:00:09
#    ---- ----------------------------------- 31.2/279.7 MB 26.1 MB/s eta 0:00:10
#    ---- ----------------------------------- 34.6/279.7 MB 25.6 MB/s eta 0:00:10
#    ----- ---------------------------------- 35.4/279.7 MB 21.6 MB/s eta 0:00:12
#    ----- ---------------------------------- 35.9/279.7 MB 19.7 MB/s eta 0:00:13
#    ----- ---------------------------------- 40.6/279.7 MB 19.9 MB/s eta 0:00:13
#    ------ --------------------------------- 44.0/279.7 MB 19.6 MB/s eta 0:00:13
#    ------ --------------------------------- 46.7/279.7 MB 19.0 MB/s eta 0:00:13
#    ------- -------------------------------- 49.5/279.7 MB 18.6 MB/s eta 0:00:13
#    ------- -------------------------------- 52.4/279.7 MB 18.2 MB/s eta 0:00:13
#    ------- -------------------------------- 54.0/279.7 MB 17.5 MB/s eta 0:00:13
#    -------- ------------------------------- 57.4/279.7 MB 17.4 MB/s eta 0:00:13
#    -------- ------------------------------- 59.8/279.7 MB 17.4 MB/s eta 0:00:13
#    -------- ------------------------------- 62.1/279.7 MB 16.8 MB/s eta 0:00:13
#    --------- ------------------------------ 64.7/279.7 MB 16.6 MB/s eta 0:00:13
#    --------- ------------------------------ 67.9/279.7 MB 16.5 MB/s eta 0:00:13
#    --------- ------------------------------ 69.5/279.7 MB 16.1 MB/s eta 0:00:14
#    ---------- ----------------------------- 70.3/279.7 MB 15.7 MB/s eta 0:00:14
#    ---------- ----------------------------- 71.0/279.7 MB 15.2 MB/s eta 0:00:14
#    ---------- ----------------------------- 71.8/279.7 MB 14.6 MB/s eta 0:00:15
#    ---------- ----------------------------- 72.4/279.7 MB 14.1 MB/s eta 0:00:15
#    ---------- ----------------------------- 73.1/279.7 MB 13.7 MB/s eta 0:00:16
#    ---------- ----------------------------- 74.2/279.7 MB 13.3 MB/s eta 0:00:16
#    ---------- ----------------------------- 75.0/279.7 MB 13.0 MB/s eta 0:00:16
#    ---------- ----------------------------- 76.0/279.7 MB 12.7 MB/s eta 0:00:17
#    ----------- ---------------------------- 77.1/279.7 MB 12.5 MB/s eta 0:00:17
#    ----------- ---------------------------- 78.6/279.7 MB 12.2 MB/s eta 0:00:17
#    ----------- ---------------------------- 80.0/279.7 MB 12.1 MB/s eta 0:00:17
#    ----------- ---------------------------- 81.8/279.7 MB 12.0 MB/s eta 0:00:17
#    ----------- ---------------------------- 83.6/279.7 MB 11.9 MB/s eta 0:00:17
#    ------------ --------------------------- 86.0/279.7 MB 11.8 MB/s eta 0:00:17
#    ------------ --------------------------- 88.3/279.7 MB 11.8 MB/s eta 0:00:17
#    ------------- -------------------------- 91.0/279.7 MB 11.8 MB/s eta 0:00:16
#    ------------- -------------------------- 93.6/279.7 MB 11.9 MB/s eta 0:00:16
#    ------------- -------------------------- 96.5/279.7 MB 11.9 MB/s eta 0:00:16
#    -------------- ------------------------- 99.6/279.7 MB 12.0 MB/s eta 0:00:15
#    -------------- ------------------------ 103.0/279.7 MB 12.1 MB/s eta 0:00:15
#    -------------- ------------------------ 106.4/279.7 MB 12.2 MB/s eta 0:00:15
#    --------------- ----------------------- 109.1/279.7 MB 12.2 MB/s eta 0:00:14
#    --------------- ----------------------- 113.2/279.7 MB 12.4 MB/s eta 0:00:14
#    ---------------- ---------------------- 117.2/279.7 MB 12.6 MB/s eta 0:00:13
#    ---------------- ---------------------- 121.4/279.7 MB 12.7 MB/s eta 0:00:13
#    ----------------- --------------------- 124.8/279.7 MB 12.8 MB/s eta 0:00:13
#    ----------------- --------------------- 126.9/279.7 MB 12.8 MB/s eta 0:00:12
#    ----------------- --------------------- 127.9/279.7 MB 12.6 MB/s eta 0:00:13
#    ------------------ -------------------- 129.5/279.7 MB 12.5 MB/s eta 0:00:13
#    ------------------ -------------------- 131.1/279.7 MB 12.4 MB/s eta 0:00:12
#    ------------------ -------------------- 132.9/279.7 MB 12.3 MB/s eta 0:00:12
#    ------------------ -------------------- 135.0/279.7 MB 12.3 MB/s eta 0:00:12
#    ------------------- ------------------- 137.4/279.7 MB 12.2 MB/s eta 0:00:12
#    ------------------- ------------------- 139.7/279.7 MB 12.2 MB/s eta 0:00:12
#    ------------------- ------------------- 142.1/279.7 MB 12.2 MB/s eta 0:00:12
#    -------------------- ------------------ 145.0/279.7 MB 12.3 MB/s eta 0:00:11
#    -------------------- ------------------ 148.1/279.7 MB 12.3 MB/s eta 0:00:11
#    --------------------- ----------------- 151.5/279.7 MB 12.4 MB/s eta 0:00:11
#    --------------------- ----------------- 154.9/279.7 MB 12.4 MB/s eta 0:00:11
#    ---------------------- ---------------- 158.6/279.7 MB 12.5 MB/s eta 0:00:10
#    ---------------------- ---------------- 162.0/279.7 MB 12.6 MB/s eta 0:00:10
#    ---------------------- ---------------- 164.9/279.7 MB 12.6 MB/s eta 0:00:10
#    ----------------------- --------------- 167.8/279.7 MB 12.6 MB/s eta 0:00:09
#    ----------------------- --------------- 171.2/279.7 MB 12.7 MB/s eta 0:00:09
#    ------------------------ -------------- 174.6/279.7 MB 12.7 MB/s eta 0:00:09
#    ------------------------ -------------- 178.0/279.7 MB 12.8 MB/s eta 0:00:08
#    ------------------------- ------------- 180.1/279.7 MB 12.7 MB/s eta 0:00:08
#    ------------------------- ------------- 182.2/279.7 MB 12.7 MB/s eta 0:00:08
#    ------------------------- ------------- 184.3/279.7 MB 12.7 MB/s eta 0:00:08
#    ------------------------- ------------- 185.3/279.7 MB 12.6 MB/s eta 0:00:08
#    ------------------------- ------------- 186.4/279.7 MB 12.5 MB/s eta 0:00:08
#    -------------------------- ------------ 187.4/279.7 MB 12.3 MB/s eta 0:00:08
#    -------------------------- ------------ 188.2/279.7 MB 12.3 MB/s eta 0:00:08
#    -------------------------- ------------ 189.3/279.7 MB 12.1 MB/s eta 0:00:08
#    -------------------------- ------------ 190.1/279.7 MB 12.0 MB/s eta 0:00:08
#    -------------------------- ------------ 191.1/279.7 MB 11.9 MB/s eta 0:00:08
#    -------------------------- ------------ 192.4/279.7 MB 11.9 MB/s eta 0:00:08
#    --------------------------- ----------- 194.0/279.7 MB 11.8 MB/s eta 0:00:08
#    --------------------------- ----------- 195.8/279.7 MB 11.7 MB/s eta 0:00:08
#    --------------------------- ----------- 197.7/279.7 MB 11.7 MB/s eta 0:00:08
#    --------------------------- ----------- 199.8/279.7 MB 11.7 MB/s eta 0:00:07
#    ---------------------------- ---------- 202.4/279.7 MB 11.7 MB/s eta 0:00:07
#    ---------------------------- ---------- 204.7/279.7 MB 11.7 MB/s eta 0:00:07
#    ---------------------------- ---------- 207.1/279.7 MB 11.7 MB/s eta 0:00:07
#    ----------------------------- --------- 210.0/279.7 MB 11.7 MB/s eta 0:00:06
#    ----------------------------- --------- 212.3/279.7 MB 11.7 MB/s eta 0:00:06
#    ------------------------------ -------- 215.7/279.7 MB 11.7 MB/s eta 0:00:06
#    ------------------------------ -------- 219.4/279.7 MB 11.8 MB/s eta 0:00:06
#    ------------------------------ -------- 221.8/279.7 MB 11.8 MB/s eta 0:00:05
#    ------------------------------- ------- 224.7/279.7 MB 11.8 MB/s eta 0:00:05
#    ------------------------------- ------- 228.9/279.7 MB 11.9 MB/s eta 0:00:05
#    -------------------------------- ------ 233.0/279.7 MB 12.0 MB/s eta 0:00:04
#    -------------------------------- ------ 235.7/279.7 MB 12.0 MB/s eta 0:00:04
#    --------------------------------- ----- 238.3/279.7 MB 12.0 MB/s eta 0:00:04
#    --------------------------------- ----- 240.9/279.7 MB 12.0 MB/s eta 0:00:04
#    --------------------------------- ----- 243.0/279.7 MB 12.0 MB/s eta 0:00:04
#    ---------------------------------- ---- 245.1/279.7 MB 12.0 MB/s eta 0:00:03
#    ---------------------------------- ---- 247.7/279.7 MB 12.0 MB/s eta 0:00:03
#    ---------------------------------- ---- 250.3/279.7 MB 12.0 MB/s eta 0:00:03
#    ----------------------------------- --- 253.0/279.7 MB 12.0 MB/s eta 0:00:03
#    ----------------------------------- --- 256.1/279.7 MB 12.0 MB/s eta 0:00:02
#    ------------------------------------ -- 259.3/279.7 MB 12.0 MB/s eta 0:00:02
#    ------------------------------------ -- 262.1/279.7 MB 12.0 MB/s eta 0:00:02
#    ------------------------------------ -- 264.8/279.7 MB 12.0 MB/s eta 0:00:02
#    ------------------------------------- - 267.4/279.7 MB 11.9 MB/s eta 0:00:02
#    ------------------------------------- - 269.5/279.7 MB 11.8 MB/s eta 0:00:01
#    ------------------------------------- - 270.5/279.7 MB 11.8 MB/s eta 0:00:01
#    ------------------------------------- - 272.4/279.7 MB 11.7 MB/s eta 0:00:01
#    --------------------------------------  275.5/279.7 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  278.7/279.7 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  279.4/279.7 MB 11.5 MB/s eta 0:00:01
#    --------------------------------------  279.4/279.7 MB 11.5 MB/s eta 0:00:01
#    --------------------------------------  279.4/279.7 MB 11.5 MB/s eta 0:00:01
#    --------------------------------------  279.4/279.7 MB 11.5 MB/s eta 0:00:01
#    --------------------------------------- 279.7/279.7 MB 11.1 MB/s eta 0:00:00
# Installing collected packages: onnxruntime-gpu
# Successfully installed onnxruntime-gpu-1.20.1
# WARNING: Ignoring invalid distribution ~ip (I:\資料\KIC\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (I:\資料\KIC\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (I:\資料\KIC\.venv\Lib\site-packages)

# %%
# yomitokuコマンドに与えるファイル指定は、日本語不可。出力先は可
# !yomitoku kobe/test -f md -o ALL_test -v --figure
# Out:
# 2025-01-08 08:45:13,901 - yomitoku.base - INFO - Initialize TextDetector
# 2025-01-08 08:45:14,705 - yomitoku.base - INFO - Initialize TextRecognizer
# 2025-01-08 08:45:15,664 - yomitoku.base - INFO - Initialize LayoutParser
# 2025-01-08 08:45:16,698 - yomitoku.base - INFO - Initialize TableStructureRecognizer
# 2025-01-08 08:45:17,500 - yomitoku.cli.main - INFO - Output directory: ALL_test
# 2025-01-08 08:45:17,502 - yomitoku.cli.main - INFO - Processing file: kobe\test\page_1.png
# 2025-01-08 08:45:18,239 - yomitoku.base - INFO - TextDetector __call__ elapsed_time: 0.623164176940918
# 2025-01-08 08:45:18,298 - yomitoku.base - INFO - LayoutParser __call__ elapsed_time: 0.681311845779419
# 2025-01-08 08:45:18,370 - yomitoku.base - INFO - TableStructureRecognizer __call__ elapsed_time: 0.07259416580200195
# 2025-01-08 08:45:18,909 - yomitoku.utils.visualizer - WARNING - libraqm is not installed. Vertical text rendering is not supported. Rendering horizontally instead.
# 2025-01-08 08:45:19,007 - yomitoku.base - INFO - TextRecognizer __call__ elapsed_time: 0.6330029964447021
# 2025-01-08 08:45:19,072 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_1_p1_ocr.jpg
# 2025-01-08 08:45:19,107 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_1_p1_layout.jpg
# 2025-01-08 08:45:19,115 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_1_p1.md
# 2025-01-08 08:45:19,117 - yomitoku.cli.main - INFO - Total Processing time: 1.61 sec
# 2025-01-08 08:45:19,117 - yomitoku.cli.main - INFO - Processing file: kobe\test\page_10.png
# 2025-01-08 08:45:19,289 - yomitoku.base - INFO - LayoutParser __call__ elapsed_time: 0.14527535438537598
# 2025-01-08 08:45:19,365 - yomitoku.base - INFO - TextDetector __call__ elapsed_time: 0.22085261344909668
# 2025-01-08 08:45:19,379 - yomitoku.base - INFO - TableStructureRecognizer __call__ elapsed_time: 0.08959579467773438
# 2025-01-08 08:45:19,655 - yomitoku.utils.visualizer - WARNING - libraqm is not installed. Vertical text rendering is not supported. Rendering horizontally instead.
# 2025-01-08 08:45:19,682 - yomitoku.base - INFO - TextRecognizer __call__ elapsed_time: 0.2992098331451416
# 2025-01-08 08:45:19,723 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_10_p1_ocr.jpg
# 2025-01-08 08:45:19,753 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_10_p1_layout.jpg
# 2025-01-08 08:45:19,753 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_10_p1.md
# 2025-01-08 08:45:19,754 - yomitoku.cli.main - INFO - Total Processing time: 0.64 sec
# 2025-01-08 08:45:19,754 - yomitoku.cli.main - INFO - Processing file: kobe\test\page_11.png
# 2025-01-08 08:45:19,919 - yomitoku.base - INFO - LayoutParser __call__ elapsed_time: 0.1332252025604248
# 2025-01-08 08:45:19,978 - yomitoku.base - INFO - TextDetector __call__ elapsed_time: 0.19179558753967285
# 2025-01-08 08:45:19,994 - yomitoku.base - INFO - TableStructureRecognizer __call__ elapsed_time: 0.07467007637023926
# 2025-01-08 08:45:20,325 - yomitoku.utils.visualizer - WARNING - libraqm is not installed. Vertical text rendering is not supported. Rendering horizontally instead.
# 2025-01-08 08:45:20,351 - yomitoku.base - INFO - TextRecognizer __call__ elapsed_time: 0.35469722747802734
# 2025-01-08 08:45:20,389 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_11_p1_ocr.jpg
# 2025-01-08 08:45:20,416 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_11_p1_layout.jpg
# 2025-01-08 08:45:20,420 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_11_p1.md
# 2025-01-08 08:45:20,422 - yomitoku.cli.main - INFO - Total Processing time: 0.67 sec
# 2025-01-08 08:45:20,422 - yomitoku.cli.main - INFO - Processing file: kobe\test\page_12.png
# 2025-01-08 08:45:20,572 - yomitoku.base - INFO - LayoutParser __call__ elapsed_time: 0.12337827682495117
# 2025-01-08 08:45:20,632 - yomitoku.base - INFO - TextDetector __call__ elapsed_time: 0.18358278274536133
# 2025-01-08 08:45:20,692 - yomitoku.base - INFO - TableStructureRecognizer __call__ elapsed_time: 0.1198270320892334
# 2025-01-08 08:45:20,947 - yomitoku.utils.visualizer - WARNING - libraqm is not installed. Vertical text rendering is not supported. Rendering horizontally instead.
# 2025-01-08 08:45:20,975 - yomitoku.base - INFO - TextRecognizer __call__ elapsed_time: 0.279926061630249
# 2025-01-08 08:45:21,018 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_12_p1_ocr.jpg
# 2025-01-08 08:45:21,050 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_12_p1_layout.jpg
# 2025-01-08 08:45:21,050 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_12_p1.md
# 2025-01-08 08:45:21,051 - yomitoku.cli.main - INFO - Total Processing time: 0.63 sec
# 2025-01-08 08:45:21,051 - yomitoku.cli.main - INFO - Processing file: kobe\test\page_13.png
# 2025-01-08 08:45:21,204 - yomitoku.base - INFO - LayoutParser __call__ elapsed_time: 0.12223649024963379
# 2025-01-08 08:45:21,298 - yomitoku.base - INFO - TextDetector __call__ elapsed_time: 0.217987060546875
# 2025-01-08 08:45:21,349 - yomitoku.base - INFO - TableStructureRecognizer __call__ elapsed_time: 0.14509248733520508
# 2025-01-08 08:45:21,613 - yomitoku.utils.visualizer - WARNING - libraqm is not installed. Vertical text rendering is not supported. Rendering horizontally instead.
# 2025-01-08 08:45:21,644 - yomitoku.base - INFO - TextRecognizer __call__ elapsed_time: 0.29167890548706055
# 2025-01-08 08:45:21,687 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_13_p1_ocr.jpg
# 2025-01-08 08:45:21,716 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_13_p1_layout.jpg
# 2025-01-08 08:45:21,716 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_13_p1.md
# 2025-01-08 08:45:21,718 - yomitoku.cli.main - INFO - Total Processing time: 0.67 sec
# 2025-01-08 08:45:21,718 - yomitoku.cli.main - INFO - Processing file: kobe\test\page_14.png
# 2025-01-08 08:45:21,885 - yomitoku.base - INFO - LayoutParser __call__ elapsed_time: 0.13702034950256348
# 2025-01-08 08:45:21,886 - yomitoku.base - INFO - TableStructureRecognizer __call__ elapsed_time: 0.001001119613647461
# 2025-01-08 08:45:21,929 - yomitoku.base - INFO - TextDetector __call__ elapsed_time: 0.18205761909484863
# 2025-01-08 08:45:22,139 - yomitoku.utils.visualizer - WARNING - libraqm is not installed. Vertical text rendering is not supported. Rendering horizontally instead.
# 2025-01-08 08:45:22,166 - yomitoku.base - INFO - TextRecognizer __call__ elapsed_time: 0.2345588207244873
# 2025-01-08 08:45:22,206 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_14_p1_ocr.jpg
# 2025-01-08 08:45:22,234 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_14_p1_layout.jpg
# 2025-01-08 08:45:22,234 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_14_p1.md
# 2025-01-08 08:45:22,237 - yomitoku.cli.main - INFO - Total Processing time: 0.52 sec
# 2025-01-08 08:45:22,237 - yomitoku.cli.main - INFO - Processing file: kobe\test\page_15.png
# 2025-01-08 08:45:22,408 - yomitoku.base - INFO - LayoutParser __call__ elapsed_time: 0.14261293411254883
# 2025-01-08 08:45:22,492 - yomitoku.base - INFO - TextDetector __call__ elapsed_time: 0.22782659530639648
# 2025-01-08 08:45:22,543 - yomitoku.base - INFO - TableStructureRecognizer __call__ elapsed_time: 0.13398480415344238
# 2025-01-08 08:45:22,801 - yomitoku.utils.visualizer - WARNING - libraqm is not installed. Vertical text rendering is not supported. Rendering horizontally instead.
# 2025-01-08 08:45:22,827 - yomitoku.base - INFO - TextRecognizer __call__ elapsed_time: 0.2803041934967041
# 2025-01-08 08:45:22,858 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_15_p1_ocr.jpg
# 2025-01-08 08:45:22,886 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_15_p1_layout.jpg
# 2025-01-08 08:45:22,886 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_15_p1.md
# 2025-01-08 08:45:22,888 - yomitoku.cli.main - INFO - Total Processing time: 0.65 sec
# 2025-01-08 08:45:22,888 - yomitoku.cli.main - INFO - Processing file: kobe\test\page_16.png
# 2025-01-08 08:45:23,050 - yomitoku.base - INFO - LayoutParser __call__ elapsed_time: 0.13259172439575195
# 2025-01-08 08:45:23,051 - yomitoku.base - INFO - TableStructureRecognizer __call__ elapsed_time: 0.0010001659393310547
# 2025-01-08 08:45:23,091 - yomitoku.base - INFO - TextDetector __call__ elapsed_time: 0.17497754096984863
# 2025-01-08 08:45:23,299 - yomitoku.utils.visualizer - WARNING - libraqm is not installed. Vertical text rendering is not supported. Rendering horizontally instead.
# 2025-01-08 08:45:23,322 - yomitoku.base - INFO - TextRecognizer __call__ elapsed_time: 0.2299356460571289
# 2025-01-08 08:45:23,356 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_16_p1_ocr.jpg
# 2025-01-08 08:45:23,382 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_16_p1_layout.jpg
# 2025-01-08 08:45:23,383 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_16_p1.md
# 2025-01-08 08:45:23,384 - yomitoku.cli.main - INFO - Total Processing time: 0.50 sec
# 2025-01-08 08:45:23,384 - yomitoku.cli.main - INFO - Processing file: kobe\test\page_2.png
# 2025-01-08 08:45:23,534 - yomitoku.base - INFO - LayoutParser __call__ elapsed_time: 0.12272071838378906
# 2025-01-08 08:45:23,615 - yomitoku.base - INFO - TextDetector __call__ elapsed_time: 0.20302367210388184
# 2025-01-08 08:45:23,616 - yomitoku.base - INFO - TableStructureRecognizer __call__ elapsed_time: 0.08130383491516113
# 2025-01-08 08:45:23,828 - yomitoku.utils.visualizer - WARNING - libraqm is not installed. Vertical text rendering is not supported. Rendering horizontally instead.
# 2025-01-08 08:45:23,853 - yomitoku.base - INFO - TextRecognizer __call__ elapsed_time: 0.23451805114746094
# 2025-01-08 08:45:23,889 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_2_p1_ocr.jpg
# 2025-01-08 08:45:23,915 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_2_p1_layout.jpg
# 2025-01-08 08:45:23,915 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_2_p1.md
# 2025-01-08 08:45:23,916 - yomitoku.cli.main - INFO - Total Processing time: 0.53 sec
# 2025-01-08 08:45:23,916 - yomitoku.cli.main - INFO - Processing file: kobe\test\page_3.png
# 2025-01-08 08:45:24,064 - yomitoku.base - INFO - LayoutParser __call__ elapsed_time: 0.12219572067260742
# 2025-01-08 08:45:24,066 - yomitoku.base - INFO - TableStructureRecognizer __call__ elapsed_time: 0.0019989013671875
# 2025-01-08 08:45:24,112 - yomitoku.base - INFO - TextDetector __call__ elapsed_time: 0.16974234580993652
# 2025-01-08 08:45:24,310 - yomitoku.utils.visualizer - WARNING - libraqm is not installed. Vertical text rendering is not supported. Rendering horizontally instead.
# 2025-01-08 08:45:24,328 - yomitoku.base - INFO - TextRecognizer __call__ elapsed_time: 0.21371960639953613
# 2025-01-08 08:45:24,367 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_3_p1_ocr.jpg
# 2025-01-08 08:45:24,393 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_3_p1_layout.jpg
# 2025-01-08 08:45:24,393 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_3_p1.md
# 2025-01-08 08:45:24,395 - yomitoku.cli.main - INFO - Total Processing time: 0.48 sec
# 2025-01-08 08:45:24,395 - yomitoku.cli.main - INFO - Processing file: kobe\test\page_4.png
# 2025-01-08 08:45:24,547 - yomitoku.base - INFO - LayoutParser __call__ elapsed_time: 0.1238865852355957
# 2025-01-08 08:45:24,631 - yomitoku.base - INFO - TextDetector __call__ elapsed_time: 0.20702886581420898
# 2025-01-08 08:45:24,633 - yomitoku.base - INFO - TableStructureRecognizer __call__ elapsed_time: 0.08514165878295898
# 2025-01-08 08:45:24,973 - yomitoku.utils.visualizer - WARNING - libraqm is not installed. Vertical text rendering is not supported. Rendering horizontally instead.
# 2025-01-08 08:45:25,009 - yomitoku.base - INFO - TextRecognizer __call__ elapsed_time: 0.37377405166625977
# 2025-01-08 08:45:25,046 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_4_p1_ocr.jpg
# 2025-01-08 08:45:25,072 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_4_p1_layout.jpg
# 2025-01-08 08:45:25,075 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_4_p1.md
# 2025-01-08 08:45:25,076 - yomitoku.cli.main - INFO - Total Processing time: 0.68 sec
# 2025-01-08 08:45:25,076 - yomitoku.cli.main - INFO - Processing file: kobe\test\page_5.png
# 2025-01-08 08:45:25,236 - yomitoku.base - INFO - LayoutParser __call__ elapsed_time: 0.131697416305542
# 2025-01-08 08:45:25,288 - yomitoku.base - INFO - TextDetector __call__ elapsed_time: 0.1836864948272705
# 2025-01-08 08:45:25,304 - yomitoku.base - INFO - TableStructureRecognizer __call__ elapsed_time: 0.06810641288757324
# 2025-01-08 08:45:25,563 - yomitoku.utils.visualizer - WARNING - libraqm is not installed. Vertical text rendering is not supported. Rendering horizontally instead.
# 2025-01-08 08:45:25,590 - yomitoku.base - INFO - TextRecognizer __call__ elapsed_time: 0.2822604179382324
# 2025-01-08 08:45:25,622 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_5_p1_ocr.jpg
# 2025-01-08 08:45:25,649 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_5_p1_layout.jpg
# 2025-01-08 08:45:25,649 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_5_p1.md
# 2025-01-08 08:45:25,652 - yomitoku.cli.main - INFO - Total Processing time: 0.58 sec
# 2025-01-08 08:45:25,652 - yomitoku.cli.main - INFO - Processing file: kobe\test\page_6.png
# 2025-01-08 08:45:25,821 - yomitoku.base - INFO - LayoutParser __call__ elapsed_time: 0.14158010482788086
# 2025-01-08 08:45:25,823 - yomitoku.base - INFO - TableStructureRecognizer __call__ elapsed_time: 0.001998424530029297
# 2025-01-08 08:45:25,871 - yomitoku.base - INFO - TextDetector __call__ elapsed_time: 0.19211721420288086
# 2025-01-08 08:45:26,141 - yomitoku.utils.visualizer - WARNING - libraqm is not installed. Vertical text rendering is not supported. Rendering horizontally instead.
# 2025-01-08 08:45:26,167 - yomitoku.base - INFO - TextRecognizer __call__ elapsed_time: 0.2938499450683594
# 2025-01-08 08:45:26,202 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_6_p1_ocr.jpg
# 2025-01-08 08:45:26,229 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_6_p1_layout.jpg
# 2025-01-08 08:45:26,231 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_6_p1.md
# 2025-01-08 08:45:26,232 - yomitoku.cli.main - INFO - Total Processing time: 0.58 sec
# 2025-01-08 08:45:26,233 - yomitoku.cli.main - INFO - Processing file: kobe\test\page_7.png
# 2025-01-08 08:45:26,398 - yomitoku.base - INFO - LayoutParser __call__ elapsed_time: 0.13958430290222168
# 2025-01-08 08:45:26,399 - yomitoku.base - INFO - TableStructureRecognizer __call__ elapsed_time: 0.0010037422180175781
# 2025-01-08 08:45:26,466 - yomitoku.base - INFO - TextDetector __call__ elapsed_time: 0.20764875411987305
# 2025-01-08 08:45:26,723 - yomitoku.utils.visualizer - WARNING - libraqm is not installed. Vertical text rendering is not supported. Rendering horizontally instead.
# 2025-01-08 08:45:26,753 - yomitoku.base - INFO - TextRecognizer __call__ elapsed_time: 0.28563642501831055
# 2025-01-08 08:45:26,789 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_7_p1_ocr.jpg
# 2025-01-08 08:45:26,816 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_7_p1_layout.jpg
# 2025-01-08 08:45:26,816 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_7_p1.md
# 2025-01-08 08:45:26,817 - yomitoku.cli.main - INFO - Total Processing time: 0.58 sec
# 2025-01-08 08:45:26,817 - yomitoku.cli.main - INFO - Processing file: kobe\test\page_8.png
# 2025-01-08 08:45:26,980 - yomitoku.base - INFO - LayoutParser __call__ elapsed_time: 0.1341872215270996
# 2025-01-08 08:45:27,044 - yomitoku.base - INFO - TextDetector __call__ elapsed_time: 0.19929242134094238
# 2025-01-08 08:45:27,059 - yomitoku.base - INFO - TableStructureRecognizer __call__ elapsed_time: 0.07910871505737305
# 2025-01-08 08:45:27,397 - yomitoku.utils.visualizer - WARNING - libraqm is not installed. Vertical text rendering is not supported. Rendering horizontally instead.
# 2025-01-08 08:45:27,428 - yomitoku.base - INFO - TextRecognizer __call__ elapsed_time: 0.36539268493652344
# 2025-01-08 08:45:27,466 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_8_p1_ocr.jpg
# 2025-01-08 08:45:27,492 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_8_p1_layout.jpg
# 2025-01-08 08:45:27,494 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_8_p1.md
# 2025-01-08 08:45:27,495 - yomitoku.cli.main - INFO - Total Processing time: 0.68 sec
# 2025-01-08 08:45:27,495 - yomitoku.cli.main - INFO - Processing file: kobe\test\page_9.png
# 2025-01-08 08:45:27,653 - yomitoku.base - INFO - LayoutParser __call__ elapsed_time: 0.13011932373046875
# 2025-01-08 08:45:27,654 - yomitoku.base - INFO - TableStructureRecognizer __call__ elapsed_time: 0.001007080078125
# 2025-01-08 08:45:27,694 - yomitoku.base - INFO - TextDetector __call__ elapsed_time: 0.1723005771636963
# 2025-01-08 08:45:27,908 - yomitoku.utils.visualizer - WARNING - libraqm is not installed. Vertical text rendering is not supported. Rendering horizontally instead.
# 2025-01-08 08:45:27,931 - yomitoku.base - INFO - TextRecognizer __call__ elapsed_time: 0.235398530960083
# 2025-01-08 08:45:27,968 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_9_p1_ocr.jpg
# 2025-01-08 08:45:27,994 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_9_p1_layout.jpg
# 2025-01-08 08:45:27,995 - yomitoku.cli.main - INFO - Output file: ALL_test\test_page_9_p1.md
# 2025-01-08 08:45:27,996 - yomitoku.cli.main - INFO - Total Processing time: 0.50 sec
